# %% [markdown]
# Machine learning Algorithm

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
observations=1000
xs=np.random.uniform(-10,10,(observations,1))
zs=np.random.uniform(-10,10,(observations,1))
inputs=np.column_stack((xs,zs))
print(inputs.shape)
# Out:
# (1000, 2)

# %%
noise=np.random.uniform(-1,1,(observations,1))
targets=2*xs-3*zs+5+noise
print(targets.shape)
# Out:
# (1000, 1)

# %%
targets=targets.reshape(observations,)
fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')
ax.plot(xs,zs,targets)
ax.set_xlabel('xs')
ax.set_ylabel('zs')
ax.set_zlabel('targets')
# Out:
# Text(0.5, 0, 'targets')

# %%
init_range=0.1
weights=np.random.uniform(-init_range,init_range,(2,1))
biases=np.random.uniform(-init_range,init_range,1)
print(weights)
print(biases)
# Out:
# [[ 0.00936992]
#  [-0.05554905]]
# [0.06439567]

# %%
learning_rate=0.02

# %%
for i in range (100):
    outputs=np.dot(inputs,weights)+biases
    deltas=outputs-targets
    loss=np.sum(deltas**2)/2/observations
    print(loss)

    deltas_scaled=deltas/observations
    weights=weights-learning_rate*np.dot(inputs.T,deltas_scaled)
    biases=biases-learning_rate*np.sum(deltas_scaled)
# Out:
# 226129.41849431593
# 7998364.619362525
# 2815836109.854497
# 1017001623167.125
# 367339004154845.3
# 1.3268215868353696e+17
# 4.792454665438306e+19
# 1.7310256290822724e+22
# 6.252432078594612e+24
# 2.2583667301427893e+27
# 8.157178236732206e+29
# 2.9463574670005253e+32
# 1.06421878637623e+35
# 3.843938279590612e+37
# 1.38842329100535e+40
# 5.014958864561775e+42
# 1.8113937281357356e+45
# 6.542720143759751e+47
# 2.3632182343711756e+50
# 8.535899901803132e+52
# 3.083151021513267e+55
# 1.1136283614865587e+58
# 4.022404737405759e+60
# 1.4528850405629327e+63
# 5.24779349393109e+65
# 1.8954931592024038e+68
# 6.846485710114514e+70
# 2.472937786730198e+73
# 8.932204865342166e+75
# 3.2262956304265036e+78
# 1.1653319255245745e+81
# 4.209157040166498e+83
# 1.5203396217612286e+86
# 5.491438175007241e+88
# 1.983497160653677e+91
# 7.1643545114045e+93
# 2.587751401074175e+96
# 9.346909485148558e+98
# 3.376086160644912e+101
# 1.2194359838627394e+104
# 4.4045798832788985e+106
# 1.5909259858587908e+109
# 5.746394797127812e+111
# 2.075587013976181e+114
# 7.496981332956493e+116
# 2.7078955846340225e+119
# 9.780868020900786e+121
# 3.5328311691607953e+124
# 1.2760519867074713e+127
# 4.6090758227964916e+129
# 1.6647895353465042e+132
# 6.013188551360482e+134
# 2.171952417197701e+137
# 7.845051360485994e+139
# 2.833617825204002e+142
# 1.023497439386611e+145
# 3.6968535386578785e+147
# 1.3352965586780446e+150
# 4.823066104654888e+152
# 1.742082423465572e+155
# 6.292369012356379e+157
# 2.27279187565061e+160
# 8.209281591527321e+162
# 2.965177100947599e+165
# 1.0710164028309603e+168
# 3.8684911426248083e+170
# 1.3972917390443134e+173
# 5.046991532405961e+175
# 1.822963867631486e+178
# 6.584511270431502e+180
# 2.3783131108775177e+183
# 8.590422312393141e+185
# 3.102844413872569e+188
# 1.1207415778396252e+191
# 4.048097541348518e+193
# 1.462165233118251e+196
# 5.281313375239362e+198
# 1.907600477409681e+201
# 6.890217116208754e+203
# 2.4887334885217767e+206
# 8.989258643707033e+208
# 3.2469033480743736e+211
# 1.1727753944555624e+214
# 4.236042710221421e+216
# 1.5300506753170958e+219
# 5.5265143181616494e+221
# 1.996166597718468e+224
# 7.210116280260354e+226
# 2.6042804660839925e+229
# 9.406612157691503e+231
# 3.397650653897573e+234
# 1.2272250383461836e+237
# 4.432713801862199e+239
# 1.6010879044399787e+242
# 5.783099456290353e+244
# 2.08884466796617e+247
# 7.544867730304558e+249
# 2.7251920614670162e+252
# 9.84334257054371e+254
# 3.555396859218794e+257

# %%
print(weights)
print(biases)
# Out:
# [[-5.00733149e+124 -5.00733149e+124 -5.00733149e+124 ... -5.00733149e+124
#   -5.00733149e+124 -5.00733149e+124]
#  [ 2.58134656e+125  2.58134656e+125  2.58134656e+125 ...  2.58134656e+125
#    2.58134656e+125  2.58134656e+125]]
# [-5.06660108e+128]
